# %%
import gzip
import json
from django.core import serializers
from pprint import pprint
from celan_app.models import Verse, Word, WordTranslation, WordVerse

# %%
fuge = Verse.objects.filter(title = "Todesfuge").first()

# %%
Verse.objects.filter(title = "Todesfuge").first().pk
# Out:
# 13377

# %%
fuge_trans = fuge.verse_translations.all()
print(f"number of translations = {fuge.verse_translations.count()}")
for trans in fuge_trans:
    pprint(list(trans.__dict__.keys()))
    pprint(trans.__dict__)
# Out:
# number of translations = 1
# ['_state',
#  'id',
#  'verse_id',
#  'lang',
#  'translator',
#  'source',
#  'year',
#  'title',
#  'text',
#  'is_preferred',
#  'created_at']
# {'_state': <django.db.models.base.ModelState object at 0x79ccb6765f10>,
#  'created_at': datetime.datetime(2026, 1, 2, 15, 24, 39, 768091, tzinfo=datetime.timezone.utc),
#  'id': 7,
#  'is_preferred': True,
#  'lang': 'ru',
#  'source': 'Ad Marginem (Пауль Целан. Стихотворения. Проза. Письма.), 2013',
#  'text': 'Черное молоко рассвета мы пьем его вечерами\n'
#          'мы пьем его в полдень и утром мы пьем его ночью\n'
#          'пьем и пьем\n'
#          'мы роем могилу в воздушном пространстве там тесно не будет\n'
#          'В том доме живет господин он играет со змеями пишет\n'
#          'он пишет когда стемнеет в Германию о золотые косы твои\n'
#          'Маргарита\n'
#          'он пишет так и встает перед домом и блещут созвездья\n'
#          'он свищет своим волкодавам\n'
# ...
